# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Convolution2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
import tensorflow as tf
import os

# %%
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
classifier = Sequential()

# %% [markdown]
# - `convolution`

# %%
classifier.add(Convolution2D(
    32, 3, 3, input_shape=(64, 64, 3), activation='relu'))

# %% [markdown]
# - `pooling`

# %%
classifier.add(MaxPooling2D(pool_size=(2, 2)))

# %% [markdown]
# - `adding second convolution layer`

# %%
classifier.add(Convolution2D(
    32, 3, 3, activation='relu'))
classifier.add(MaxPooling2D(pool_size=(2, 2)))

# %% [markdown]
# - `flattening`

# %%
classifier.add(Flatten())

# %% [markdown]
# - `full connection`

# %%
# hidden layer
classifier.add(Dense(activation='relu', units=128))

# classifier.add(Dense(activation='relu', units=64))

# last layer / output layer
# sigmoid coz we have only 1 output, if the o/p was more than 2 use softmax
classifier.add(Dense(activation='sigmoid', units=1))

# %%
classifier.compile(
    optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
tboard_log_dir = os.path.join("logs")

tensorboard_callback = tf.keras.callbacks.TensorBoard(
    log_dir=tboard_log_dir, histogram_freq=1)

# classifier.fit(x=X,
#                y=y,
#                epochs=10,
#                batch_size=10,
#                callbacks=[tensorboard_callback])

# %% [markdown]
# - `image augmentation technique to overcome over-fitting `

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1./255)

# %%
train = train_datagen.flow_from_directory(
    'data/train/',
    target_size=(64, 64),
    batch_size=32,
    class_mode='binary')
# Out:
# Found 2400 images belonging to 2 classes.

# %%
test = test_datagen.flow_from_directory(
    'data/test/',
    target_size=(64, 64),
    batch_size=32,
    class_mode='binary')
# Out:
# Found 600 images belonging to 2 classes.

# %%
train_steps = train.n // 32  # 2000/32
test_steps = test.n // 32  # 1000/32
print(train_steps, test_steps)
# Out:
# 75 18

# %%
classifier.fit(
    train,
    steps_per_epoch=train_steps,
    epochs=100,  # 322
    validation_data=test,
    validation_steps=test_steps,
    callbacks=[tensorboard_callback])  # callbacks=[tensorboard_callback]
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 75 steps, validate for 18 steps
# Epoch 1/100
# 75/75 [==============================] - 14s 183ms/step - loss: 0.6927 - accuracy: 0.5267 - val_loss: 0.6889 - val_accuracy: 0.6163
# Epoch 2/100
# 75/75 [==============================] - 12s 159ms/step - loss: 0.6893 - accuracy: 0.5346 - val_loss: 0.6815 - val_accuracy: 0.6146
# Epoch 3/100
# 75/75 [==============================] - 12s 161ms/step - loss: 0.6843 - accuracy: 0.5679 - val_loss: 0.6797 - val_accuracy: 0.5608
# Epoch 4/100
# 75/75 [==============================] - 12s 157ms/step - loss: 0.6802 - accuracy: 0.5813 - val_loss: 0.6798 - val_accuracy: 0.5417
# Epoch 5/100
# 75/75 [==============================] - 12s 156ms/step - loss: 0.6642 - accuracy: 0.6004 - val_loss: 0.6509 - val_accuracy: 0.5938
# Epoch 6/100
# 75/75 [==============================] - 11s 152ms/step - loss: 0.6529 - accuracy: 0.6187 - val_loss: 0.6532 - val_accuracy: 0.6181
# Epoch 7/100
# 75/75 [==============================] - 11s 151ms/step - loss: 0.6501 - accuracy: 0.6208 - val_loss: 0.6509 - val_accuracy: 0.5816
# Epoch 8/100
# 75/75 [==============================] - 11s 149ms/step - loss: 0.6384 - accuracy: 0.6342 - val_loss: 0.6416 - val_accuracy: 0.6024
# Epoch 9/100
# 75/75 [==============================] - 11s 150ms/step - loss: 0.6292 - accuracy: 0.6346 - val_loss: 0.6513 - val_accuracy: 0.6094
# Epoch 10/100
# 75/75 [==============================] - 12s 154ms/step - loss: 0.6241 - accuracy: 0.6442 - val_loss: 0.6609 - val_accuracy: 0.5972
# Epoch 11/100
# 75/75 [==============================] - 11s 148ms/step - loss: 0.6245 - accuracy: 0.6508 - val_loss: 0.6375 - val_accuracy: 0.6094
# Epoch 12/100
# 75/75 [==============================] - 12s 162ms/step - loss: 0.6221 - accuracy: 0.6442 - val_loss: 0.6414 - val_accuracy: 0.6094
# Epoch 13/100
# 75/75 [==============================] - 12s 157ms/step - loss: 0.6017 - accuracy: 0.6704 - val_loss: 0.6714 - val_accuracy: 0.5972
# Epoch 14/100
# 75/75 [==============================] - 11s 152ms/step - loss: 0.6057 - accuracy: 0.6712 - val_loss: 0.6336 - val_accuracy: 0.6059
# Epoch 15/100
# 75/75 [==============================] - 11s 149ms/step - loss: 0.6029 - accuracy: 0.6742 - val_loss: 0.6854 - val_accuracy: 0.5833
# Epoch 16/100
# 75/75 [==============================] - 11s 151ms/step - loss: 0.5906 - accuracy: 0.6858 - val_loss: 0.6862 - val_accuracy: 0.5920
# Epoch 17/100
# 75/75 [==============================] - 11s 153ms/step - loss: 0.5985 - accuracy: 0.6808 - val_loss: 0.6268 - val_accuracy: 0.6319
# Epoch 18/100
# 75/75 [==============================] - 11s 149ms/step - loss: 0.5807 - accuracy: 0.6846 - val_loss: 0.6413 - val_accuracy: 0.6163
# Epoch 19/100
# 75/75 [==============================] - 11s 152ms/step - loss: 0.5806 - accuracy: 0.6896 - val_loss: 0.6404 - val_accuracy: 0.6181
# Epoch 20/100
# 75/75 [==============================] - 12s 154ms/step - loss: 0.5920 - accuracy: 0.6871 - val_loss: 0.6286 - val_accuracy: 0.6250
# Epoch 21/100
# 75/75 [==============================] - 15s 200ms/step - loss: 0.5813 - accuracy: 0.6908 - val_loss: 0.7065 - val_accuracy: 0.5816
# Epoch 22/100
# 75/75 [==============================] - 12s 164ms/step - loss: 0.5802 - accuracy: 0.6913 - val_loss: 0.7446 - val_accuracy: 0.5816
# Epoch 23/100
# 75/75 [==============================] - 11s 150ms/step - loss: 0.5664 - accuracy: 0.6996 - val_loss: 0.6705 - val_accuracy: 0.6059
# Epoch 24/100
# 75/75 [==============================] - 12s 154ms/step - loss: 0.5672 - accuracy: 0.7025 - val_loss: 0.6306 - val_accuracy: 0.6285
# Epoch 25/100
# 75/75 [==============================] - 12s 154ms/step - loss: 0.5774 - accuracy: 0.6958 - val_loss: 0.6310 - val_accuracy: 0.6250
# Epoch 26/100
# 75/75 [==============================] - 12s 162ms/step - loss: 0.5617 - accuracy: 0.7108 - val_loss: 0.6446 - val_accuracy: 0.6267
# Epoch 27/100
# 75/75 [==============================] - 11s 148ms/step - loss: 0.4817 - accuracy: 0.7708 - val_loss: 0.6387 - val_accuracy: 0.6615
# Epoch 66/100
# 75/75 [==============================] - 11s 146ms/step - loss: 0.4884 - accuracy: 0.7625 - val_loss: 0.6317 - val_accuracy: 0.6615
# Epoch 67/100
# 75/75 [==============================] - 11s 152ms/step - loss: 0.4780 - accuracy: 0.7696 - val_loss: 0.8459 - val_accuracy: 0.6076
# Epoch 68/100
# 75/75 [==============================] - 11s 147ms/step - loss: 0.4979 - accuracy: 0.7513 - val_loss: 0.6884 - val_accuracy: 0.6354
# Epoch 69/100
# 75/75 [==============================] - 11s 151ms/step - loss: 0.4878 - accuracy: 0.7583 - val_loss: 0.7186 - val_accuracy: 0.6354
# Epoch 70/100
# 75/75 [==============================] - 12s 159ms/step - loss: 0.4775 - accuracy: 0.7646 - val_loss: 0.6994 - val_accuracy: 0.6389
# Epoch 71/100
# 75/75 [==============================] - 12s 157ms/step - loss: 0.4713 - accuracy: 0.7758 - val_loss: 0.6563 - val_accuracy: 0.6510
# Epoch 72/100
# 75/75 [==============================] - 14s 181ms/step - loss: 0.4876 - accuracy: 0.7579 - val_loss: 0.6755 - val_accuracy: 0.6389
# Epoch 73/100
# 75/75 [==============================] - 12s 164ms/step - loss: 0.4855 - accuracy: 0.7663 - val_loss: 0.6422 - val_accuracy: 0.6562
# Epoch 74/100
# 75/75 [==============================] - 11s 147ms/step - loss: 0.4632 - accuracy: 0.7800 - val_loss: 0.6343 - val_accuracy: 0.6493
# Epoch 75/100
# 75/75 [==============================] - 11s 146ms/step - loss: 0.4714 - accuracy: 0.7696 - val_loss: 0.6516 - val_accuracy: 0.6476
# Epoch 76/100
# 75/75 [==============================] - 11s 149ms/step - loss: 0.4530 - accuracy: 0.7779 - val_loss: 0.6565 - val_accuracy: 0.6510
# Epoch 77/100
# 75/75 [==============================] - 11s 149ms/step - loss: 0.4595 - accuracy: 0.7792 - val_loss: 0.6775 - val_accuracy: 0.6389
# Epoch 78/100
# 75/75 [==============================] - 11s 147ms/step - loss: 0.4590 - accuracy: 0.7858 - val_loss: 0.6574 - val_accuracy: 0.6597
# Epoch 79/100
# 75/75 [==============================] - 11s 148ms/step - loss: 0.4514 - accuracy: 0.7821 - val_loss: 0.6780 - val_accuracy: 0.6545
# Epoch 80/100
# 75/75 [==============================] - 11s 148ms/step - loss: 0.4613 - accuracy: 0.7854 - val_loss: 0.6444 - val_accuracy: 0.6667
# Epoch 81/100
# 75/75 [==============================] - 11s 147ms/step - loss: 0.4810 - accuracy: 0.7642 - val_loss: 0.6474 - val_accuracy: 0.6424
# Epoch 82/100
# 75/75 [==============================] - 11s 147ms/step - loss: 0.4590 - accuracy: 0.7829 - val_loss: 0.6632 - val_accuracy: 0.6458
# Epoch 83/100
# 75/75 [==============================] - 11s 147ms/step - loss: 0.4618 - accuracy: 0.7775 - val_loss: 0.6571 - val_accuracy: 0.6684
# Epoch 84/100
# 75/75 [==============================] - 11s 148ms/step - loss: 0.4638 - accuracy: 0.7738 - val_loss: 0.6646 - val_accuracy: 0.6528
# Epoch 85/100
# 75/75 [==============================] - 11s 149ms/step - loss: 0.4614 - accuracy: 0.7767 - val_loss: 0.6897 - val_accuracy: 0.6406
# Epoch 86/100
# 75/75 [==============================] - 11s 150ms/step - loss: 0.4630 - accuracy: 0.7742 - val_loss: 0.6475 - val_accuracy: 0.6562
# Epoch 87/100
# 75/75 [==============================] - 11s 147ms/step - loss: 0.4526 - accuracy: 0.7917 - val_loss: 0.6970 - val_accuracy: 0.6597
# Epoch 88/100
# 75/75 [==============================] - 12s 156ms/step - loss: 0.4446 - accuracy: 0.7867 - val_loss: 0.6580 - val_accuracy: 0.6719
# Epoch 89/100
# 75/75 [==============================] - 12s 158ms/step - loss: 0.4290 - accuracy: 0.7962 - val_loss: 0.6652 - val_accuracy: 0.6632
# Epoch 90/100
# 75/75 [==============================] - 11s 148ms/step - loss: 0.4509 - accuracy: 0.7842 - val_loss: 0.6454 - val_accuracy: 0.6632
# Epoch 91/100
# 75/75 [==============================] - 11s 146ms/step - loss: 0.4334 - accuracy: 0.7946 - val_loss: 0.6538 - val_accuracy: 0.6649
# Epoch 92/100
# 75/75 [==============================] - 11s 146ms/step - loss: 0.4583 - accuracy: 0.7837 - val_loss: 0.6940 - val_accuracy: 0.6441
# Epoch 93/100
# 75/75 [==============================] - 11s 147ms/step - loss: 0.4444 - accuracy: 0.7837 - val_loss: 0.6948 - val_accuracy: 0.6493
# Epoch 94/100
# 75/75 [==============================] - 11s 148ms/step - loss: 0.4467 - accuracy: 0.7929 - val_loss: 0.6924 - val_accuracy: 0.6406
# Epoch 95/100
# 75/75 [==============================] - 11s 148ms/step - loss: 0.4464 - accuracy: 0.7887 - val_loss: 0.6667 - val_accuracy: 0.6580
# Epoch 96/100
# 75/75 [==============================] - 11s 147ms/step - loss: 0.4346 - accuracy: 0.7992 - val_loss: 0.7084 - val_accuracy: 0.6510
# Epoch 97/100
# 75/75 [==============================] - 11s 148ms/step - loss: 0.4399 - accuracy: 0.7850 - val_loss: 0.7054 - val_accuracy: 0.6528
# Epoch 98/100
# 75/75 [==============================] - 11s 153ms/step - loss: 0.4416 - accuracy: 0.7979 - val_loss: 0.7025 - val_accuracy: 0.6597
# Epoch 99/100
# 75/75 [==============================] - 14s 184ms/step - loss: 0.4613 - accuracy: 0.7771 - val_loss: 0.6451 - val_accuracy: 0.6649
# Epoch 100/100
# 75/75 [==============================] - 12s 155ms/step - loss: 0.4417 - accuracy: 0.7950 - val_loss: 0.6570 - val_accuracy: 0.6632

# %%
# %tensorboard --logdir logs
# Out:
# Reusing TensorBoard on port 6006 (pid 15492), started 0:26:28 ago. (Use '!kill 15492' to kill it.)
#       <iframe id="tensorboard-frame-4507b43af21db8d0" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-4507b43af21db8d0");
#           const url = new URL("/", window.location);
#           url.port = 6006;
#           frame.src = url;
#         })();
#       </script>

# %%
classifier.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 21, 21, 32)        896
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 10, 10, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 3, 32)          9248
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 1, 32)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 32)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               4224
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 14,497
# Trainable params: 14,497
# Non-trainable params: 0
# _________________________________________________________________
